# %%
# Sample list defined directly in the program
numbers = [12, 7, 24, 35, 42, 88, 19, 50, 63, 100]

# Filter even numbers using list comprehension
even_numbers = [num for num in numbers if num % 2 == 0]

# Output the results
print("Sample List: ", numbers)
print("Even Numbers:", even_numbers)
# Out:
# Sample List:  [12, 7, 24, 35, 42, 88, 19, 50, 63, 100]
# Even Numbers: [12, 24, 42, 88, 50, 100]

# %%
# Get input from the user
word = input("Enter a single word: ")

# Reverse the word using slicing
reversed_word = word[::-1]

# Print the reversed word
print("Reversed word:", reversed_word)
# Out:
# Enter a single word:  Sahaj
# Reversed word: jahaS

# %%
# Get a sentence from the user
sentence = input("Enter a sentence: ")

# Option 1: Reverse every character in the sentence
reversed_characters = sentence[::-1]

# Option 2: Reverse the order of the words
reversed_words = " ".join(sentence.split()[::-1])

# Display the results
print("\nCharacter-by-character reversed:")
print(reversed_characters)

print("\nWord-order reversed:")
print(reversed_words)
# Out:
# Enter a sentence:  I am Saransh
# Character-by-character reversed:
# hsnaraS ma I
#
# Word-order reversed:
# Saransh am I
