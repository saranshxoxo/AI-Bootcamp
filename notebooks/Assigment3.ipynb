# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
print("Environment ready!")
print("NumPy:", np.__version__)
print("pandas:", pd.__version__)
print("scikit-learn:", __import__("sklearn").__version__)
# Out:
# Environment ready!
# NumPy: 2.5.3
# pandas: 3.0.6
# scikit-learn: 1.9.1

# %%
df = pd.read_csv("student_performance.csv")
df.head()
# Out:
#    StudentID  G1  G2  G3      Mjob     Fjob  age address  studytime  failures  \
# 0          1   6   2   2   teacher  at_home   21   rural          3         1
# 1          2  19  11  18    health  teacher   18   rural          1         1
# 2          3  14   7  19    health    other   20   urban          1         1
# 3          4  10   2   6  services   health   21   urban          3         1
# 4          5   7   0  19    health   health   18   rural          4         1
#
#   schoolsup famsup paid activities nursery higher internet romantic  \
# 0        no    yes  yes        yes     yes    yes       no      yes
# 1        no     no   no         no     yes     no       no       no
# 2       yes    yes  yes         no      no     no      yes      yes
# 3       yes     no  yes         no     yes     no       no       no
# 4        no     no  yes         no     yes    yes      yes       no
#
#   Unnamed: 18
# 0     =AI("")
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df["result"] = df["G3"].apply(lambda x: "Pass" if x >= 10 else "Fail")

print(df.groupby("result")[["G1", "G2", "G3", "studytime", "failures"]].mean())
# Out:
#               G1        G2         G3  studytime  failures
# result
# Fail    9.703704  9.388889   3.518519   2.203704  1.481481
# Pass    8.195652  7.913043  15.586957   2.217391  1.260870

# %%
plt.figure(figsize=(7,4))

plt.scatter(
    df["studytime"],
    df["G3"],
    c=df["result"].map({"Fail": 0, "Pass": 1})
)

plt.xlabel("Study Time")
plt.ylabel("Final Grade (G3)")
plt.title("Student Performance Pattern")
plt.show()

# %%
X = df[["G1", "G2", "studytime", "failures"]]
y = df["result"]

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (100, 4)
# y shape: (100,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
print("Training rows:", len(X_train))
print("Testing rows :", len(X_test))
# Out:
# Training rows: 80
# Testing rows : 20

# %%
model = DecisionTreeClassifier(max_depth=3, random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
print("Model trained!")
# Out:
# Model trained!

# %%
plt.figure(figsize=(13,7))
plot_tree(
    model,
    feature_names=X.columns,
    class_names=["Fail", "Pass"],
    filled=True,
    rounded=True
)
plt.title("What did the model learn?")
plt.show()
